# %%
# 구글 코랩 사용시 
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

data = pd.read_csv("/content/drive/MyDrive/jobkorea_all.csv")

# %%
import os
os.chdir("/content/drive/MyDrive")

# %%
from preprocess_all import preprocess_answer, preprocess_job

# %%
data = preprocess_answer(data)
data = preprocess_job(data)
# Out:
# /content/drive/MyDrive/preprocess_all.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[text.notna()] = text[text.notna()].apply(lambda x: re.sub(pattern, patterns[pattern], x))
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:1020: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# /content/drive/MyDrive/preprocess_all.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
